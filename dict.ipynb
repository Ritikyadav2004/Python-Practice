# %%
mydict={}

#dict with integer key 
mydict = {1:"Ritik",2:"Universe",3:"Metaverse",4:"Metaphoripia"}
print(mydict)
# Out:
# {1: 'Ritik', 2: 'Universe', 3: 'Metaverse', 4: 'Metaphoripia'}

# %%
mydict={
    "Name":"Ritik Yadav",
    "Zone":"Indore",
    "Degree":"M-tech",
    "College ":"IIT Indore",
    "DOB":"12-12-2025",
    "linkdIn id":"ritikyadav004",
    "Bio":"Software Engineer at Google"
}
print(mydict)


print(mydict['Name'])
print(mydict['Bio'])
print(mydict['Zone'])

mydict['Degree']="PHD"
print(f"Updated Dictionery {mydict}")
mydict
# Out:
# {'Name': 'Ritik Yadav', 'Zone': 'Indore', 'Degree': 'M-tech', 'College ': 'IIT Indore', 'DOB': '12-12-2025', 'linkdIn id': 'ritikyadav004', 'Bio': 'Software Engineer at Google'}
# Ritik Yadav
# Software Engineer at Google
# Indore
# Updated Dictionery {'Name': 'Ritik Yadav', 'Zone': 'Indore', 'Degree': 'PHD', 'College ': 'IIT Indore', 'DOB': '12-12-2025', 'linkdIn id': 'ritikyadav004', 'Bio': 'Software Engineer at Google'}
# {'Name': 'Ritik Yadav',
#  'Zone': 'Indore',
#  'Degree': 'PHD',
#  'College ': 'IIT Indore',
#  'DOB': '12-12-2025',
#  'linkdIn id': 'ritikyadav004',
#  'Bio': 'Software Engineer at Google'}

# %%
mydict={
    "Name":"Ritik Yadav",
    "Zone":"Indore",
    "Degree":"M-tech",
    "College ":"IIT Indore",
    "DOB":"12-12-2025",
    "linkdIn id":"ritikyadav004",
    "Bio":"Software Engineer at Google"
}

mydict.popitem()
# Out:
# ('Bio', 'Software Engineer at Google')

# %%
mydict={
    "Name":"Ritik Yadav",
    "Zone":"Indore",
    "Degree":"M-tech",
    "College ":"IIT Indore",
    "DOB":"12-12-2025",
    "linkdIn id":"ritikyadav004",
    "Bio":"Software Engineer at Google"
}
mydict.pop('Bio')
print(mydict)

mydict.pop('Degree')
mydict

#Print last elemnt 
mydict.popitem()

del mydict["Name"]
mydict

#Cler dict 
mydict = {
    "Name": "Ritik",
    "Zone": "Indore",
    "DOB": "12-12-2025"
}

mydict.clear()

print(mydict)



#remove dict
del mydict
# Out:
# {'Name': 'Ritik Yadav', 'Zone': 'Indore', 'Degree': 'M-tech', 'College ': 'IIT Indore', 'DOB': '12-12-2025', 'linkdIn id': 'ritikyadav004'}
# {}

# %%
ordDict={2:4,3:9,4:16}
copyDict = ordDict.copy()
copyDict
# Out:
# {2: 4, 3: 9, 4: 16}

# %%
subject={}.fromkeys(['Maths','Science','English','Hindi'],0)
print(subject)



print(subject.keys())
print(subject.values())

print(subject.items()) #list ke form ke ayega
# Out:
# {'Maths': 0, 'Science': 0, 'English': 0, 'Hindi': 0}
# dict_keys(['Maths', 'Science', 'English', 'Hindi'])
# dict_values([0, 0, 0, 0])
# dict_items([('Maths', 0), ('Science', 0), ('English', 0), ('Hindi', 0)])

# %% [markdown]
# Dict Comprehension

# %%
subject={}.fromkeys(['Maths','Science','English','Hindi'],0)

for  pair in subject.items():
    print(pair)
# Out:
# ('Maths', 0)
# ('Science', 0)
# ('English', 0)
# ('Hindi', 0)

# %%
d={'a':1,'b':2,'c':3,'d':4}
#KYA KRNA HE KISPER KRNA HE KESE KRNA HE 
newDict = {k+'1':v+1 for k,v in d.items() if v>2}
print(newDict)
# Out:
# {'c1': 4, 'd1': 5}

# %%
d={'a':1,'b':3,'c':3,'d':4}
#KYA KRNA HE KISPER KRNA HE KESE KRNA HE 
#k+'c'
d={k+'c':v*2 for k,v in d.items() if v>2}
d
# Out:
# {'bc': 6, 'cc': 6, 'dc': 8}
