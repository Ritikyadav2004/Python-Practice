# %%
def findUnitDigit(a, b):

  if (2 <= a <= 9):
    if a in [2, 3, 7, 8]:  # they follow cyclicity
      n = b // 4
      if (4 * n + 1 == b):
        return a

      elif (4 * n + 2 == b):
        if a in [2, 3]:
          return a * a
        elif a in [7, 8]:
          return (a * a) % 10

      elif (4 * n + 3 == b):
        if (a == 2):
          return a * a * a
        elif a in [3, 7, 8]:
          return (a * a * a) % 10

      elif (4 * n  == b):
        return (a * a * a * a) % 10

    elif a in [0, 1, 5, 6]:
      return a

    # now we only remaining with 4 and 9
    # a must be either 4 or 9
    else:
      if (b % 2 == 0):
        return (a * a) % 10
      else:
        return a

  else:  # 10 <= 20
    a = a % 10
    if a in [2, 3, 7, 8]:  # they follow cyclicity
      n = b // 4
      if (4 * n + 1 == b):
        return a

      elif (4 * n + 2 == b):
        if a in [2, 3]:
          return a * a
        elif a in [7, 8]:
          return (a * a) % 10

      elif (4 * n + 3 == b):
        if (a == 2):
          return a * a * a
        elif a in [3, 7, 8]:
          return (a * a * a) % 10

      elif (4 * n == b):
        return (a * a * a * a) % 10

    elif a in [0, 1, 5, 6]:
      return a

    # now we only remaining with 4 and 9
    # a must be either 4 or 9
    else:
      if (b % 2 == 0):
        return (a * a) % 10
      else:
        return a
#tBasic test case
print(findUnitDigit(12,227))
print(findUnitDigit(3,10))
print(findUnitDigit(6,2))
print(findUnitDigit(10,3))
#edge case
print(findUnitDigit(20,10000000000))
print(findUnitDigit(13,7))
print(findUnitDigit(3,7))
print(findUnitDigit(12,15))
# Out:
# 8
# 9
# 6
# 0
# 0
# 7
# 7
# 8
