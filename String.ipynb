# %%
Str = "Hey There Iam Ritik Yadav"
print(Str)

print(len(Str))
# Out:
# Hey There Iam Ritik Yadav
# 25

# %%
Str = "I am learning String. This keeps me Energetic."
whatDoYouLearning = "What are you learning? "

print(whatDoYouLearning + Str)
# Out:
# What are you learning? I am learning String. This keeps me Energetic.

# %%
for ch in "Hey There This is String And Iam Itrating in this how are you":
    print(ch,end=" ",sep="*")
# Out:
# H e y   T h e r e   T h i s   i s   S t r i n g   A n d   I a m   I t r a t i n g   i n   t h i s   h o w   a r e   y o u

# %%
print("Hey There This is String And Iam Itrating in this how are you".lower())
print("Hey There This is String And Iam Itrating in this how are you".split())
# Out:
# hey there this is string and iam itrating in this how are you
# ['Hey', 'There', 'This', 'is', 'String', 'And', 'Iam', 'Itrating', 'in', 'this', 'how', 'are', 'you']

# %%
"Hey There This is String And Iam Itrating in this how are you".find("are")
# Out:
# 54

# %%
s1="Bad Morning"
s2=s1.replace("Bad","Good")

print(f"String 1 {s1}\nString 2 {s2}")
# Out:
# String 1 Bad Morning
# String 2 Good Morning

# %%
Str="madam"
for i in range(len(Str)//2):
    if Str[i]!=Str[len(Str)-1-i]:
        print("Not Pallindrom")
        break
else:
    print("Pallindrome")

if Str==reversed(Str):
    print("Pallindrome")
