# %%
from MyMath import x
print(x)
# Out:
# 888

# %%
from MyMath import add
print(add(5,6))
# Out:
# 11

# %%
from MyMath import pdt
print(pdt(2,3))
# Out:
# 6

# %%
from MyMath import divide
print(divide(100,0))
# Out:
# Can devided with 0

# %%
from MyMath import sumOfnTerms
print(sumOfnTerms(100))
# Out:
# 5050

# %%
from MyMath import square
nums=9
print(square(nums))
# Out:
# 81

# %%
# import MyMath as mt
# nums= [1,2,3,4,5,6,7,8]
# print(mt.evenList(nums))

import temp as mt

result = mt.evenList([10, 15, 20,1,2,3,4,5])
print(result)
# Out:
# [10, 20, 2, 4]
